# %%
#Step 1- Import the text file/article that has to be used for MCQ generation

file=open(r"C:\Users\BISWAJIT KAR\MCQgen\experiment\Artificial Intelligence.txt") #"r" deontes read version open
text=file.read()

# %%
text
# Out:
# "Title: Exploring the Transformative Realm of Artificial Intelligence\n\nIntroduction:\nArtificial Intelligence (AI) stands at the forefront of technological innovation, captivating minds with its promise of revolutionizing virtually every aspect of human life. Defined as the simulation of human intelligence processes by machines, AI encompasses a broad spectrum of technologies, from simple algorithms to complex neural networks. This essay delves into the multifaceted world of AI, exploring its history, current applications, ethical considerations, and future implications.\n\nA Historical Journey:\nThe roots of AI trace back to ancient myths and philosophical inquiries into the nature of intelligence. However, the formalization of AI as a field of study emerged in the mid-20th century, marked by the groundbreaking work of Alan Turing and the Dartmouth Conference in 1956. Early AI systems focused on rule-based reasoning and symbolic manipulation, exemplified by programs like IBMâ€™s Deep Blue, which defeated world chess champion Garry Kasparov in 1997.\n\nThe Rise of Machine Learning:\nIn recent decades, the advent of machine learning has propelled AI into new realms of possibility. Machine learning algorithms enable computers to learn from data, iteratively improving performance without explicit programming. Techniques such as neural networks, support vector machines, and decision trees have revolutionized fields like image recognition, natural language processing, and autonomous vehicles. Companies like Google, Facebook, and Amazon leverage machine learning to personalize user experiences and optimize business operations.\n\nEthical Considerations:\nAs AI technologies proliferate, ethical concerns surrounding their deployment become increasingly salient. Issues such as algorithmic bias, data privacy, and job displacement underscore the need for responsible AI development and regulation. Biased algorithms can perpetuate societal inequalities, while the unchecked collection of personal data raises questions about surveillance and autonomy. Moreover, the prospect of widespread automation threatens to disrupt traditional employment structures, necessitating policies to mitigate economic disparities and ensure equitable access to opportunities.\n\nAI in Healthcare:\nOne of the most promising applications of AI lies in healthcare, where it has the potential to revolutionize diagnostics, treatment planning, and patient care. Machine learning algorithms analyze medical images with unprecedented accuracy, aiding in the early detection of diseases like cancer and Alzheimer's. Natural language processing facilitates the extraction of insights from vast amounts of clinical data, enabling more personalized and effective interventions. Furthermore, AI-powered virtual assistants enhance patient engagement and streamline administrative tasks, freeing up healthcare professionals to focus on delivering quality care.\n\nThe Future of Work:\nThe widespread adoption of AI technologies raises profound questions about the future of work and human labor. While automation promises to increase efficiency and productivity, it also threatens to displace millions of jobs across various industries. Routine tasks in manufacturing, transportation, and customer service are particularly susceptible to automation, necessitating a reevaluation of education and workforce development strategies. Reskilling and upskilling programs can empower workers to adapt to the evolving job market, fostering a more resilient and inclusive economy.\n\nAI and Creativity:\nContrary to popular misconceptions, AI is not limited to analytical tasks but also possesses creative potential. Generative models like deep learning-based neural networks can produce art, music, and literature that rival human creations. From algorithmic poetry to computer-generated paintings, AI-generated content challenges conventional notions of authorship and creativity. While some view AI as a threat to  ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('popular')
##Importing the needed files and packages
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\BISWAJIT
# [nltk_data]     KAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\BISWAJIT
# [nltk_data]     KAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\BISWAJIT
# [nltk_data]    |     KAR\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
# pip install rake_nltk

# %%
from rake_nltk import Rake

r = Rake()

# %%
#Step 2- Extract the important words(keywords) from the text article that can be used to create MCQ using RAKE

from nltk.corpus import stopwords #Stopwords are the words that we need to avoid while considering keyword extraction
import string


# Define the function to extract important words
def getImportantWords(art):
    r = Rake(stopwords=stopwords.words('english') + list(string.punctuation))
    r.extract_keywords_from_text(art)
    keyphrases = r.get_ranked_phrases_with_scores()
    result = [keyphrase for _, keyphrase in keyphrases[:25]]  # Get the top 25 keyphrases
    return result

# Extract important words (keywords) from the text article
impWords = getImportantWords(text)
print(impWords)
# Out:
# ['iteratively improving performance without explicit programming', 'defeated world chess champion garry kasparov', 'powered virtual assistants enhance patient engagement', 'machine learning algorithms analyze medical images', 'revolutionized fields like image recognition', 'narrow tasks within predefined domains', 'generated content challenges conventional notions', 'machine learning algorithms enable computers', 'generative models like deep learning', 'ai technologies raises profound questions', 'revolutionizing virtually every aspect', 'disrupt traditional employment structures', 'fields like deep learning', 'jobs across various industries', 'amazon leverage machine learning', 'personal data raises questions', 'programs like ibmâ €™', 'natural language processing facilitates', 'ai permeates every aspect', 'deployment become increasingly salient', 'agi raises philosophical questions', 'society poses complex challenges', 'achieving artificial general intelligence', 'also possesses creative potential', 'early ai systems focused']

# %%
#Step 3- Split the whole text article into an array/list of individual sentences. This will help us fetch the sentences related to the keywords easily

from nltk.tokenize import sent_tokenize
def splitTextToSents(art):
    s=[sent_tokenize(art)]
    s=[y for x in s for y in x]
    s=[sent.strip() for sent in s if len(sent)>15] #Removes all the sentences that have length less than 15 so that we can ensure that our questions have enough length for context
    return s
sents=splitTextToSents(text) #Achieve a well splitted set of sentences from the text article
print(sents)
# Out:
# ['Title: Exploring the Transformative Realm of Artificial Intelligence\n\nIntroduction:\nArtificial Intelligence (AI) stands at the forefront of technological innovation, captivating minds with its promise of revolutionizing virtually every aspect of human life.', 'Defined as the simulation of human intelligence processes by machines, AI encompasses a broad spectrum of technologies, from simple algorithms to complex neural networks.', 'This essay delves into the multifaceted world of AI, exploring its history, current applications, ethical considerations, and future implications.', 'A Historical Journey:\nThe roots of AI trace back to ancient myths and philosophical inquiries into the nature of intelligence.', 'However, the formalization of AI as a field of study emerged in the mid-20th century, marked by the groundbreaking work of Alan Turing and the Dartmouth Conference in 1956.', 'Early AI systems focused on rule-based reasoning and symbolic manipulation, exemplified by programs like IBMâ€™s Deep Blue, which defeated world chess champion Garry Kasparov in 1997.', 'The Rise of Machine Learning:\nIn recent decades, the advent of machine learning has propelled AI into new realms of possibility.', 'Machine learning algorithms enable computers to learn from data, iteratively improving performance without explicit programming.', 'Techniques such as neural networks, support vector machines, and decision trees have revolutionized fields like image recognition, natural language processing, and autonomous vehicles.', 'Companies like Google, Facebook, and Amazon leverage machine learning to personalize user experiences and optimize business operations.', 'Ethical Considerations:\nAs AI technologies proliferate, ethical concerns surrounding their deployment become increasingly salient.', 'Issues such as algorithmic bias, data privacy, and job displacement underscore the need for responsible AI development and regulation.', 'Biased algorithms can perpetuate societal inequalities, while the unchecked collection of personal data raises questions about surveillance and autonomy.', 'Moreover, the prospect of widespread automation threatens to disrupt traditional employment structures, necessitating policies to mitigate economic disparities and ensure equitable access to opportunities.', 'AI in Healthcare:\nOne of the most promising applications of AI lies in healthcare, where it has the potential to revolutionize diagnostics, treatment planning, and patient care.', "Machine learning algorithms analyze medical images with unprecedented accuracy, aiding in the early detection of diseases like cancer and Alzheimer's.", 'Natural language processing facilitates the extraction of insights from vast amounts of clinical data, enabling more personalized and effective interventions.', 'Furthermore, AI-powered virtual assistants enhance patient engagement and streamline administrative tasks, freeing up healthcare professionals to focus on delivering quality care.', 'The Future of Work:\nThe widespread adoption of AI technologies raises profound questions about the future of work and human labor.', 'While automation promises to increase efficiency and productivity, it also threatens to displace millions of jobs across various industries.', 'Routine tasks in manufacturing, transportation, and customer service are particularly susceptible to automation, necessitating a reevaluation of education and workforce development strategies.', 'Reskilling and upskilling programs can empower workers to adapt to the evolving job market, fostering a more resilient and inclusive economy.', 'AI and Creativity:\nContrary to popular misconceptions, AI is not limited to analytical tasks but also possesses creative potential.', 'Generative models like deep learning-based neural networks can produce art, music, and literature that rival human creations.', 'From algorithmic poetry to computer-generated paintings, AI-generated content challenges conventional notions of author ...

# %%
#Step 4- Map the sentences which contain the keywords to the related keywords so that we can easily lookup the sentences related to the keywords

from flashtext import KeywordProcessor
def mapSents(impWords,sents):
    processor=KeywordProcessor() #Using keyword processor as our processor for this task
    keySents={}
    for word in impWords:
        keySents[word]=[]
        processor.add_keyword(word) #Adds key word to the processor
    for sent in sents:
        found=processor.extract_keywords(sent) #Extract the keywords in the sentence
        for each in found:
            keySents[each].append(sent) #For each keyword found, map the sentence to the keyword
    for key in keySents.keys():
        temp=keySents[key]
        temp=sorted(temp,key=len,reverse=True) #Sort the sentences according to their decreasing length in order to ensure the quality of question for the MCQ 
        keySents[key]=temp
    return keySents
mappedSents=mapSents(impWords,sents) #Achieve the sentences that contain the keywords and map those sentences to the keywords using this function
print(mappedSents)
# Out:
# {'iteratively improving performance without explicit programming': ['Machine learning algorithms enable computers to learn from data, iteratively improving performance without explicit programming.'], 'defeated world chess champion garry kasparov': ['Early AI systems focused on rule-based reasoning and symbolic manipulation, exemplified by programs like IBMâ€™s Deep Blue, which defeated world chess champion Garry Kasparov in 1997.'], 'powered virtual assistants enhance patient engagement': ['Furthermore, AI-powered virtual assistants enhance patient engagement and streamline administrative tasks, freeing up healthcare professionals to focus on delivering quality care.'], 'machine learning algorithms analyze medical images': ["Machine learning algorithms analyze medical images with unprecedented accuracy, aiding in the early detection of diseases like cancer and Alzheimer's."], 'revolutionized fields like image recognition': ['Techniques such as neural networks, support vector machines, and decision trees have revolutionized fields like image recognition, natural language processing, and autonomous vehicles.'], 'narrow tasks within predefined domains': ['The Quest for Artificial General Intelligence:\nWhile current AI systems excel at narrow tasks within predefined domains, achieving artificial general intelligence (AGI) remains an elusive goal.'], 'generated content challenges conventional notions': ['From algorithmic poetry to computer-generated paintings, AI-generated content challenges conventional notions of authorship and creativity.'], 'machine learning algorithms enable computers': ['Machine learning algorithms enable computers to learn from data, iteratively improving performance without explicit programming.'], 'generative models like deep learning': ['Generative models like deep learning-based neural networks can produce art, music, and literature that rival human creations.'], 'ai technologies raises profound questions': ['The Future of Work:\nThe widespread adoption of AI technologies raises profound questions about the future of work and human labor.'], 'revolutionizing virtually every aspect': ['Title: Exploring the Transformative Realm of Artificial Intelligence\n\nIntroduction:\nArtificial Intelligence (AI) stands at the forefront of technological innovation, captivating minds with its promise of revolutionizing virtually every aspect of human life.'], 'disrupt traditional employment structures': ['Moreover, the prospect of widespread automation threatens to disrupt traditional employment structures, necessitating policies to mitigate economic disparities and ensure equitable access to opportunities.'], 'fields like deep learning': ['Despite significant progress in fields like deep learning, researchers grapple with fundamental challenges such as abstraction, context awareness, and causal reasoning.'], 'jobs across various industries': ['While automation promises to increase efficiency and productivity, it also threatens to displace millions of jobs across various industries.'], 'amazon leverage machine learning': ['Companies like Google, Facebook, and Amazon leverage machine learning to personalize user experiences and optimize business operations.'], 'personal data raises questions': ['Biased algorithms can perpetuate societal inequalities, while the unchecked collection of personal data raises questions about surveillance and autonomy.'], 'programs like ibmâ €™': [], 'natural language processing facilitates': ['Natural language processing facilitates the extraction of insights from vast amounts of clinical data, enabling more personalized and effective interventions.'], 'ai permeates every aspect': ['From healthcare and education to art and governance, AI permeates every aspect of modern life, offering unprecedented opportunities and posing formidable challenges.'], 'deployment become increasingly salient': ['Ethical Considerations:\nAs AI technologies proliferate, ethical concerns surrounding their deployme ...

# %%
# pip install pywsd

# %%
#Step 5- Get the sense of the word. In order to attain a quality set of distractors we need to get the right sense of the keyword. This is explained in detail in the seperate alogrithm documentation

from pywsd.similarity import max_similarity
from pywsd.lesk import adapted_lesk
from pywsd.lesk import simple_lesk
from pywsd.lesk import cosine_lesk
from nltk.corpus import wordnet as wn
def getWordSense(sent,word):
    word=word.lower() 
    if len(word.split())>0: #Splits the word with underscores(_) instead of spaces if there are multiple words
        word=word.replace(" ","_")
    synsets=wn.synsets(word,'n') #Sysnets from Google are invoked
    if synsets:
        wup=max_similarity(sent,word,'wup',pos='n')
        adapted_lesk_output = adapted_lesk(sent, word, pos='n')
        lowest_index=min(synsets.index(wup),synsets.index(adapted_lesk_output))
        return synsets[lowest_index]
    else:
        return None
# Out:
# Warming up PyWSD (takes ~10 secs)... took 9.169601917266846 secs.

# %%
#Step 6- Get distractor from WordNet. These distractors work on the basis of hypernym and hyponym explained in detail in the documentation.

def getDistractors(syn,word):
    dists=[]
    word=word.lower()
    actword=word
    if len(word.split())>0: #Splits the word with underscores(_) instead of spaces if there are multiple words
        word.replace(" ","_")
    hypernym = syn.hypernyms() #Gets the hypernyms of the word
    if len(hypernym)==0: #If there are no hypernyms for the current word, we simple return the empty list of distractors
        return dists
    for each in hypernym[0].hyponyms(): #Other wise we find the relevant hyponyms for the hypernyms
        name=each.lemmas()[0].name()
        if(name==actword):
            continue
        name=name.replace("_"," ")
        name=" ".join(w.capitalize() for w in name.split())
        if name is not None and name not in dists: #If the word is not already present in the list and is different from he actial word
            dists.append(name)
    return dists

# %%
#Step 7- The primary goal of this step is to take our MCQ quality one step further. The WordNet might some times fail to produce a hypernym for some words.
#In that case the ConcepNet comes into play as they help achieve our distractors when there are no hypernyms present for it in the WordNet. More about this is discussed
#in the algorithm documentation.

import requests
import json
def getDistractors2(word):
    word=word.lower()
    actword=word
    if len(word.split())>0: #Splits the word with underscores(_) instead of spaces if there are multiple words
        word=word.replace(" ","_")
    dists=[]
    url= "http://api.conceptnet.io/query?node=/c/en/%s/n&rel=/r/PartOf&start=/c/en/%s&limit=5"%(word,word) #To get ditractors from ConceptNet's API
    obj=requests.get(url).json()
    for edge in obj['edges']:
        link=edge['end']['term']
        url2="http://api.conceptnet.io/query?node=%s&rel=/r/PartOf&end=%s&limit=10"%(link,link)
        obj2=requests.get(url2).json()
        for edge in obj2['edges']:
            word2=edge['start']['label']
            if word2 not in dists and actword.lower() not in word2.lower(): #If the word is not already present in the list and is different from he actial word
                dists.append(word2)
    return dists

# %%
import random
import re

# %%
##step-8

mappedDists = {}

for each in impWords:
    if each not in mappedSents or not mappedSents[each]:
        continue
    distractors = random.sample([k for k in impWords if k != each], 3)
    mappedDists[each] = distractors

# %%
# Step 9- The final step is to present our MCQ in a nice and readable manner.

num_mcqs = int(input("Enter the number of questions you want : "))  # control the number of MCQs generated

print("**************************************        Multiple Choice Questions        *******************************")
print()

iterator = 1  # To keep the count of the questions
for each in mappedDists:
    if iterator > num_mcqs:
        break  # exit the loop if the desired number of MCQs has been reached
    if each not in mappedSents or not mappedSents[each]:  # Check if the keyword is not in mappedSents or if its list of sentences is empty
        continue  # Skip this keyword if it's not found in mappedSents or has no mapped sentences
    sent = mappedSents[each][0]
    p = re.compile(each, re.IGNORECASE)  # Converts into regular expression for pattern matching
    op = p.sub("________", sent)  # Replaces the keyword with underscores(blanks)
    correct_answer = each.capitalize()  # The correct answer
    print("Question %s-> "%(iterator), op)  # Prints the question along with a question number
    options = [each.capitalize()] + mappedDists[each]  # Capitalizes the options
    options = options[:4]  # Selects only 4 options
    opts = ['a', 'b', 'c', 'd']
    random.shuffle(options)  # Shuffle the options so that order is not always same
    for i, ch in enumerate(options):
        print("\t", opts[i], ") ", ch)  # Print the options
    print("Correct Answer: ", correct_answer)  # Print the correct answer
    print()
    iterator += 1  # Increase the counter
# Out:
# Enter the number of questions you want : 22
# **************************************        Multiple Choice Questions        *******************************
#
# Question 1->  Machine learning algorithms enable computers to learn from data, ________.
# 	 a )  revolutionized fields like image recognition
# 	 b )  fields like deep learning
# 	 c )  ai technologies raises profound questions
# 	 d )  Iteratively improving performance without explicit programming
# Correct Answer:  Iteratively improving performance without explicit programming
#
# Question 2->  Early AI systems focused on rule-based reasoning and symbolic manipulation, exemplified by programs like IBMâ€™s Deep Blue, which ________ in 1997.
# 	 a )  deployment become increasingly salient
# 	 b )  revolutionized fields like image recognition
# 	 c )  disrupt traditional employment structures
# 	 d )  Defeated world chess champion garry kasparov
# Correct Answer:  Defeated world chess champion garry kasparov
#
# Question 3->  Furthermore, AI-________ and streamline administrative tasks, freeing up healthcare professionals to focus on delivering quality care.
# 	 a )  natural language processing facilitates
# 	 b )  ai technologies raises profound questions
# 	 c )  Powered virtual assistants enhance patient engagement
# 	 d )  society poses complex challenges
# Correct Answer:  Powered virtual assistants enhance patient engagement
#
# Question 4->  ________ with unprecedented accuracy, aiding in the early detection of diseases like cancer and Alzheimer's.
# 	 a )  also possesses creative potential
# 	 b )  narrow tasks within predefined domains
# 	 c )  Machine learning algorithms analyze medical images
# 	 d )  society poses complex challenges
# Correct Answer:  Machine learning algorithms analyze medical images
#
# Question 5->  Techniques such as neural networks, support vector machines, and decision trees have ________, natural language processing, and autonomous vehicles.
# 	 a )  ai technologies raises profound questions
# 	 b )  machine learning algorithms enable computers
# 	 c )  Revolutionized fields like image recognition
# 	 d )  machine learning algorithms analyze medical images
# Correct Answer:  Revolutionized fields like image recognition
#
# Question 6->  The Quest for Artificial General Intelligence:
# While current AI systems excel at ________, achieving artificial general intelligence (AGI) remains an elusive goal.
# 	 a )  revolutionizing virtually every aspect
# 	 b )  Narrow tasks within predefined domains
# 	 c )  amazon leverage machine learning
# 	 d )  powered virtual assistants enhance patient engagement
# Correct Answer:  Narrow tasks within predefined domains
#
# Question 7->  From algorithmic poetry to computer-generated paintings, AI-________ of authorship and creativity.
# 	 a )  Generated content challenges conventional notions
# 	 b )  iteratively improving performance without explicit programming
# 	 c )  machine learning algorithms analyze medical images
# 	 d )  programs like ibmâ €™
# Correct Answer:  Generated content challenges conventional notions
#
# Question 8->  ________ to learn from data, iteratively improving performance without explicit programming.
# 	 a )  revolutionizing virtually every aspect
# 	 b )  machine learning algorithms analyze medical images
# 	 c )  Machine learning algorithms enable computers
# 	 d )  amazon leverage machine learning
# Correct Answer:  Machine learning algorithms enable computers
#
# Question 9->  ________-based neural networks can produce art, music, and literature that rival human creations.
# 	 a )  narrow tasks within predefined domains
# 	 b )  jobs across various industries
# 	 c )  Generative models like deep learning
# 	 d )  powered virtual assistants enhance patient engagement
# Correct Answer:  Generative models like deep learning
#
# Question 10->  The Future of Work:
# The widespread adoption of ________ about the future of work and human labor.
# 	 a )  amazon leverage machine learning
# 	 b )  natural language processing facilitates
# 	 c )  agi raises philosophical questions
# 	 d )  Ai technologies raises profound questions
# Correct Answer:  Ai technologies raises profound questions
#
# Question 11->  Title: Exploring the Transformative Realm of Artificial Intelligence
#
# Introduction:
# Artificial Intelligence (AI) stands at the forefront of technological innovation, captivating minds with its promise of ________ of human life.
# 	 a )  Revolutionizing virtually every aspect
# 	 b )  defeated world chess champion garry kasparov
# 	 c )  disrupt traditional employment structures
# 	 d )  generative models like deep learning
# Correct Answer:  Revolutionizing virtually every aspect
#
# Question 12->  Moreover, the prospect of widespread automation threatens to ________, necessitating policies to mitigate economic disparities and ensure equitable access to opportunities.
# 	 a )  jobs across various industries
# 	 b )  ai technologies raises profound questions
# 	 c )  Disrupt traditional employment structures
# 	 d )  agi raises philosophical questions
# Correct Answer:  Disrupt traditional employment structures
#
# Question 13->  Despite significant progress in ________, researchers grapple with fundamental challenges such as abstraction, context awareness, and causal reasoning.
# 	 a )  revolutionizing virtually every aspect
# 	 b )  generative models like deep learning
# 	 c )  powered virtual assistants enhance patient engagement
# 	 d )  Fields like deep learning
# Correct Answer:  Fields like deep learning
#
# Question 14->  While automation promises to increase efficiency and productivity, it also threatens to displace millions of ________.
# 	 a )  early ai systems focused
# 	 b )  ai technologies raises profound questions
# 	 c )  generative models like deep learning
# 	 d )  Jobs across various industries
# Correct Answer:  Jobs across various industries
#
# Question 15->  Companies like Google, Facebook, and ________ to personalize user experiences and optimize business operations.
# 	 a )  disrupt traditional employment structures
# 	 b )  revolutionized fields like image recognition
# 	 c )  Amazon leverage machine learning
# 	 d )  also possesses creative potential
# Correct Answer:  Amazon leverage machine learning
#
# Question 16->  Biased algorithms can perpetuate societal inequalities, while the unchecked collection of ________ about surveillance and autonomy.
# 	 a )  Personal data raises questions
# 	 b )  revolutionizing virtually every aspect
# 	 c )  defeated world chess champion garry kasparov
# 	 d )  powered virtual assistants enhance patient engagement
# Correct Answer:  Personal data raises questions
#
# Question 17->  ________ the extraction of insights from vast amounts of clinical data, enabling more personalized and effective interventions.
# 	 a )  defeated world chess champion garry kasparov
# 	 b )  revolutionized fields like image recognition
# 	 c )  ai permeates every aspect
# 	 d )  Natural language processing facilitates
# Correct Answer:  Natural language processing facilitates
#
# Question 18->  From healthcare and education to art and governance, ________ of modern life, offering unprecedented opportunities and posing formidable challenges.
# 	 a )  generative models like deep learning
# 	 b )  fields like deep learning
# 	 c )  Ai permeates every aspect
# 	 d )  natural language processing facilitates
# Correct Answer:  Ai permeates every aspect
#
# Question 19->  Ethical Considerations:
# As AI technologies proliferate, ethical concerns surrounding their ________.
# 	 a )  Deployment become increasingly salient
# 	 b )  personal data raises questions
# 	 c )  early ai systems focused
# 	 d )  natural language processing facilitates
# Correct Answer:  Deployment become increasingly salient
#
# Question 20->  The pursuit of ________ about the nature of consciousness and the limits of computational intelligence.
# 	 a )  ai permeates every aspect
# 	 b )  jobs across various industries
# 	 c )  generated content challenges conventional notions
# 	 d )  Agi raises philosophical questions
# Correct Answer:  Agi raises philosophical questions
#
# Question 21->  AI and Society:
# The integration of AI into ________ and opportunities for governance, ethics, and human flourishing.
# 	 a )  fields like deep learning
# 	 b )  deployment become increasingly salient
# 	 c )  personal data raises questions
# 	 d )  Society poses complex challenges
# Correct Answer:  Society poses complex challenges
#
# Question 22->  The Quest for Artificial General Intelligence:
# While current AI systems excel at narrow tasks within predefined domains, ________ (AGI) remains an elusive goal.
# 	 a )  Achieving artificial general intelligence
# 	 b )  narrow tasks within predefined domains
# 	 c )  programs like ibmâ €™
# 	 d )  natural language processing facilitates
# Correct Answer:  Achieving artificial general intelligence

# %%
import streamlit as st
import re
import random
import pke
from nltk.corpus import stopwords
import string
import requests
import json
from nltk.tokenize import sent_tokenize
from nltk.corpus import wordnet as wn
from pywsd.similarity import max_similarity
from pywsd.lesk import adapted_lesk, simple_lesk, cosine_lesk

def getImportantWords(art):
    extractor = pke.unsupervised.MultipartiteRank()
    extractor.load_document(input=art, language='en')
    pos = {'PROPN'}
    stops = list(string.punctuation)
    stops += ['-lrb-', '-rrb-', '-lcb-', '-rcb-', '-lsb-', '-rsb-']
    stops += stopwords.words('english')
    extractor.candidate_selection(pos=pos)
    extractor.candidate_weighting()
    keyphrases = extractor.get_n_best(n=25)
    result = [keyphrase[0] for keyphrase in keyphrases]
    return result

def splitTextToSents(art):
    s = [nltk.sent_tokenize(art)]
    s = [y for x in s for y in x]
    s = [sent.strip() for sent in s if len(sent) > 15]
    return s

def mapSents(impWords, sents):
    processor = KeywordProcessor()
    keySents = {}
    for word in impWords:
        keySents[word] = []
        processor.add_keyword(word)
    for sent in sents:
        found = processor.extract_keywords(sent)
        for each in found:
            keySents[each].append(sent)
    for key in keySents.keys():
        temp = keySents[key]
        temp = sorted(temp, key=len, reverse=True)
        keySents[key] = temp
    return keySents

def getWordSense(sent, word):
    word = word.lower()
    if len(word.split()) > 0:
        word = word.replace(" ", "_")
    synsets = wn.synsets(word, 'n')
    if synsets:
        wup = max_similarity(sent, word, 'wup', pos='n')
        adapted_lesk_output = adapted_lesk(sent, word, pos='n')
        lowest_index = min(synsets.index(wup), synsets.index(adapted_lesk_output))
        return synsets[lowest_index]
    else:
        return None

def generateDistractors(word, synset):
    distractors = []
    for lemma in synset.lemmas():
        if lemma.name() != word:
            distractors.append(lemma.name())
    return distractors

def get_distractors_and_senses(mappedSents, impWords):
    mappedDists = {}
    for each in mappedSents:
        synset = getWordSense(mappedSents[each][0], each)
        if synset:
            distractors = generateDistractors(each, synset)
            mappedDists[each] = distractors
    return mappedDists

def main():
    st.title("MCQ Generator")

    # Load the text file
    file = open(r"C:\Users\BISWAJIT KAR\MCQgen\experiment\Artificial Intelligence.txt", "r")
    text = file.read()

    # Extract important words (keywords) from the text article
    impWords = getImportantWords(text)

    # Split the whole text article into an array/list of individual sentences
    sents = splitTextToSents(text)

    # Map the sentences which contain the keywords to the related keywords
    mappedSents = mapSents(impWords, sents)

    # Get the sense of the word and map distractors to the keywords
    mappedDists = get_distractors_and_senses(mappedSents, impWords)

    # Display the MCQs
    st.header("Multiple Choice Questions")
    iterator = 1
    for each in mappedDists:
        sent = mappedSents[each][0]
        p = re.compile(each, re.IGNORECASE)
        op = p.sub("________", sent)
        correct_answer = each.capitalize()
        options = [correct_answer] + mappedDists[each]
        random.shuffle(options)

        st.subheader(f"Question {iterator}")
        st.write(op)
        st.write("Correct answer: ", correct_answer)
        st.write("Your answer: ", st.radio("", options))
        st.write("")
        iterator += 1

if __name__ == "__main__":
    main()
